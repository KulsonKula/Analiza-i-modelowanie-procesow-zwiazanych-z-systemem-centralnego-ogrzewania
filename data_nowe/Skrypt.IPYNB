# %%
import pandas as pd
import numpy as np
import datetime
import os 
import glob 
np.set_printoptions(precision=5, suppress=True)

# %%
dni_tygodnia_mapa = {
    'Monday': 1,
    'Tuesday': 2,
    'Wednesday': 3,
    'Thursday': 4,
    'Friday': 5,
    'Saturday': 6,
    'Sunday': 7
}

# %%
dataset = pd.read_csv('inputData/ewh_profile[0].csv')

dataset
# Out:
#          Summer_Timestamps  Summer_Water_Consumption  \
# 0      2018-02-05 00:00:00                       0.0
# 1      2018-02-05 00:01:00                       0.0
# 2      2018-02-05 00:02:00                       0.0
# 3      2018-02-05 00:03:00                       0.0
# 4      2018-02-05 00:04:00                       0.0
# ...                    ...                       ...
# 40315  2018-02-04 23:55:00                       0.0
# 40316  2018-02-04 23:56:00                       0.0
# 40317  2018-02-04 23:57:00                       0.0
# 40318  2018-02-04 23:58:00                       0.0
# 40319  2018-02-04 23:59:00                       0.0
#
#        Summer_Ambient_Temperature  Summer_Power    Autumn_Timestamps  \
# 0                            21.0        3246.0  2018-04-09 00:00:00
# 1                            21.0        3245.0  2018-04-09 00:01:00
# 2                            21.0        3235.0  2018-04-09 00:02:00
# 3                            21.0           0.0  2018-04-09 00:03:00
# 4                            21.0           0.0  2018-04-09 00:04:00
# ...                           ...           ...                  ...
# 40315                        20.0        3237.0  2018-04-08 23:55:00
# 40316                        20.0        3242.0  2018-04-08 23:56:00
# 40317                        20.0        3232.0  2018-04-08 23:57:00
# 40318                        20.0        3248.0  2018-04-08 23:58:00
# 40319                        20.0        3250.0  2018-04-08 23:59:00
#
#        Autumn_Water_Consumption  Autumn_Ambient_Temperature  Autumn_Power  \
# 0                           0.0                        20.0           0.0
# 1                           0.0                        19.0           0.0
# 2                           0.0                        19.0           0.0
# 3                           0.0                        19.0           0.0
# 4                           0.0                        19.0           0.0
# ...                         ...                         ...           ...
# 40315                       0.0                        20.0           0.0
# 40316                       0.0                        20.0           0.0
# 40317                       0.0                        20.0           0.0
# 40318                       0.0                        20.0           0.0
# 40319                       0.0                        20.0           0.0
#
#          Winter_Timestamps  Winter_Water_Consumption  \
# 0      2017-08-21 00:00:00                       0.0
# 1      2017-08-21 00:01:00                       0.0
# 2      2017-08-21 00:02:00                       0.0
# 3      2017-08-21 00:03:00                       0.0
# 4      2017-08-21 00:04:00                       0.0
# ...                    ...                       ...
# 40315  2017-08-20 23:55:00                       0.0
# 40316  2017-08-20 23:56:00                       0.0
# 40317  2017-08-20 23:57:00                       0.0
# 40318  2017-08-20 23:58:00                       0.0
# 40319  2017-08-20 23:59:00                       0.0
#
#        Winter_Ambient_Temperature  Winter_Power    Spring_Timestamps  \
# 0                             7.0           0.0  2017-10-02 00:00:00
# 1                             7.0           0.0  2017-10-02 00:01:00
# 2                             7.0           0.0  2017-10-02 00:02:00
# 3                             7.0           0.0  2017-10-02 00:03:00
# 4                             7.0           0.0  2017-10-02 00:04:00
# ...                           ...           ...                  ...
# 40315                         7.0           0.0  2017-10-01 23:55:00
# 40316                         7.0           0.0  2017-10-01 23:56:00
# 40317                         7.0           0.0  2017-10-01 23:57:00
# 40318                         7.0           0.0  2017-10-01 23:58:00
# 40319                         7.0           0.0  2017-10-01 23:59:00
#
#        Spring_Water_Consumption  Spring_Ambient_Temperature  Spring_Power
# 0                           0.0                        16.0           0.0
# 1                           0.0                        16.0           0.0
# 2                           0.0                        16.0           0.0
# 3                           0.0                        16.0           0.0
# 4                           0.0                        16.0           0.0
# ...                         ...                         ...           ...
# 40315                       0.0                        14.0           0.0
# 40316                       0.0                        14.0           0.0
# 40317                       0.0                        14.0           0.0
# 40318                       0.0                        14.0           0.0
# 40319                       0.0                        14.0           0.0
#
# [40320 rows x 16 columns]

# %% [markdown]
# Przetwarzanie jednego pliku

# %%
# dane_1 = pd.DataFrame({"Pora roku": [], "Dzień tygodnia": [], "Czas dnia": [], "Przeplyw":[]})
# dane_2 = pd.DataFrame({"Pora roku": [], "Dzień tygodnia": [], "Czas dnia": [], "Przeplyw":[]})
# dane_3 = pd.DataFrame({"Pora roku": [], "Dzień tygodnia": [], "Czas dnia": [], "Przeplyw":[]})
# dane_4 = pd.DataFrame({"Pora roku": [], "Dzień tygodnia": [], "Czas dnia": [], "Przeplyw":[]})

# for i in range(len(dataset)):
#     dt = dataset.loc[i,"Summer_Timestamps"]   
#     data, time =dt.split(' ')
#     year, month, day  = (int(x) for x in data.split('-'))    
#     ans = datetime.date(year, month, day)

#     hours, minutes,null= time.split(":")
#     time=(int(hours)*60+int(minutes))/(60*24)

#     dane_1.loc[len(dane_1)]={'Pora roku':2,'Dzień tygodnia':dni_tygodnia_mapa[ans.strftime("%A")],'Czas dnia':time}
# for i in range(len(dataset)):
#     # ----------------------
#     # ----------------------
#     dt = dataset.loc[i,"Autumn_Timestamps"]   
#     data, time =dt.split(' ')
#     year, month, day  = (int(x) for x in data.split('-'))    
#     ans = datetime.date(year, month, day)

#     hours, minutes,null= time.split(":")
#     time=(int(hours)*60+int(minutes))/(60*24)

#     dane_2.loc[len(dane_2)]={'Pora roku':3,'Dzień tygodnia':dni_tygodnia_mapa[ans.strftime("%A")],'Czas dnia':time}
# for i in range(len(dataset)):
#     # #----------------------
#     #----------------------
#     dt = dataset.loc[i,"Winter_Timestamps"]   
#     data, time =dt.split(' ')
#     year, month, day  = (int(x) for x in data.split('-'))    
#     ans = datetime.date(year, month, day)

#     hours, minutes,null= time.split(":")
#     time=(int(hours)*60+int(minutes))/(60*24)

#     dane_3.loc[len(dane_3)]={'Pora roku':4,'Dzień tygodnia':dni_tygodnia_mapa[ans.strftime("%A")],'Czas dnia':time}
# for i in range(len(dataset)):
#     # #----------------------
#     # #----------------------
#     dt = dataset.loc[i,"Spring_Timestamps"]   
#     data, time =dt.split(' ')
#     year, month, day  = (int(x) for x in data.split('-'))    
#     ans = datetime.date(year, month, day)

#     hours, minutes,null= time.split(":")
#     time=(int(hours)*60+int(minutes))/(60*24)

#     dane_4.loc[len(dane_4)]={'Pora roku':1,'Dzień tygodnia':dni_tygodnia_mapa[ans.strftime("%A")],'Czas dnia':time}
# dane= pd.concat([dane_1,dane_2,dane_3,dane_4], ignore_index=True)

# %%
# dane.to_csv('dane_scalone.csv', index=False)

# %%
dane = pd.DataFrame({"Pora roku": [], "Dzien tygodnia": [], "Czas dnia": [], "Przeplyw":[]})
path = os.getcwd() 
csv_files = glob.glob(os.path.join(path, "inputData/*.csv")) 

for f in csv_files: 
      
    dt = pd.read_csv(f) 
      
    dane_1 = pd.DataFrame({"Pora roku": [], "Dzien tygodnia": [], "Czas dnia": [], "Przeplyw":[]})
    dane_2 = pd.DataFrame({"Pora roku": [], "Dzien tygodnia": [], "Czas dnia": [], "Przeplyw":[]})
    dane_3 = pd.DataFrame({"Pora roku": [], "Dzien tygodnia": [], "Czas dnia": [], "Przeplyw":[]})
    dane_4 = pd.DataFrame({"Pora roku": [], "Dzien tygodnia": [], "Czas dnia": [], "Przeplyw":[]})

    for i in range(len(dataset)):
        dt = dataset.loc[i,"Summer_Timestamps"]   
        data, time =dt.split(' ')
        year, month, day  = (int(x) for x in data.split('-'))    
        ans = datetime.date(year, month, day)

        hours, minutes,null= time.split(":")
        time=(int(hours)*60+int(minutes))/(60*24)

        dane_1.loc[len(dane_1)]={'Pora roku':2,'Dzien tygodnia':dni_tygodnia_mapa[ans.strftime("%A")],'Czas dnia':time, 'Przeplyw': dataset.loc[i,"Summer_Water_Consumption"]}
    for i in range(len(dataset)):
        # ----------------------
        # ----------------------
        dt = dataset.loc[i,"Autumn_Timestamps"]   
        data, time =dt.split(' ')
        year, month, day  = (int(x) for x in data.split('-'))    
        ans = datetime.date(year, month, day)

        hours, minutes,null= time.split(":")
        time=(int(hours)*60+int(minutes))/(60*24)

        dane_2.loc[len(dane_2)]={'Pora roku':3,'Dzien tygodnia':dni_tygodnia_mapa[ans.strftime("%A")],'Czas dnia':time, 'Przeplyw': dataset.loc[i,"Autumn_Water_Consumption"]}
    for i in range(len(dataset)):
        # #----------------------
        #----------------------
        dt = dataset.loc[i,"Winter_Timestamps"]   
        data, time =dt.split(' ')
        year, month, day  = (int(x) for x in data.split('-'))    
        ans = datetime.date(year, month, day)

        hours, minutes,null= time.split(":")
        time=(int(hours)*60+int(minutes))/(60*24)

        dane_3.loc[len(dane_3)]={'Pora roku':4,'Dzien tygodnia':dni_tygodnia_mapa[ans.strftime("%A")],'Czas dnia':time, 'Przeplyw': dataset.loc[i,"Winter_Water_Consumption"]}
    for i in range(len(dataset)):
        # #----------------------
        # #----------------------
        dt = dataset.loc[i,"Spring_Timestamps"]   
        data, time =dt.split(' ')
        year, month, day  = (int(x) for x in data.split('-'))    
        ans = datetime.date(year, month, day)
    
        hours, minutes,null= time.split(":")
        time=(int(hours)*60+int(minutes))/(60*24)
    
        dane_4.loc[len(dane_4)]={'Pora roku':1,'Dzien tygodnia':dni_tygodnia_mapa[ans.strftime("%A")],'Czas dnia':time, 'Przeplyw': dataset.loc[i,"Spring_Water_Consumption"]}
    dane= pd.concat([dane, dane_1,dane_2,dane_3,dane_4], ignore_index=True)
    print(dane)
    dane.to_csv('dane_scalone_backup.csv', index=False)


dane.to_csv('dane_scalone.csv', index=False)
# Out:
#         Pora roku  Dzień tygodnia  Czas dnia  Przeplyw
# 0             2.0             1.0   0.000000       0.0
# 1             2.0             1.0   0.000694       0.0
# 2             2.0             1.0   0.001389       0.0
# 3             2.0             1.0   0.002083       0.0
# 4             2.0             1.0   0.002778       0.0
# ...           ...             ...        ...       ...
# 161275        1.0             7.0   0.996528       0.0
# 161276        1.0             7.0   0.997222       0.0
# 161277        1.0             7.0   0.997917       0.0
# 161278        1.0             7.0   0.998611       0.0
# 161279        1.0             7.0   0.999306       0.0
#
# [161280 rows x 4 columns]
#         Pora roku  Dzień tygodnia  Czas dnia  Przeplyw
# 0             2.0             1.0   0.000000       0.0
# 1             2.0             1.0   0.000694       0.0
# 2             2.0             1.0   0.001389       0.0
# 3             2.0             1.0   0.002083       0.0
# 4             2.0             1.0   0.002778       0.0
# ...           ...             ...        ...       ...
# 322555        1.0             7.0   0.996528       0.0
# 322556        1.0             7.0   0.997222       0.0
# 322557        1.0             7.0   0.997917       0.0
# 322558        1.0             7.0   0.998611       0.0
# 322559        1.0             7.0   0.999306       0.0
#
# [322560 rows x 4 columns]
#         Pora roku  Dzień tygodnia  Czas dnia  Przeplyw
# 0             2.0             1.0   0.000000       0.0
# 1             2.0             1.0   0.000694       0.0
# 2             2.0             1.0   0.001389       0.0
# 3             2.0             1.0   0.002083       0.0
# 4             2.0             1.0   0.002778       0.0
# ...           ...             ...        ...       ...
# 483835        1.0             7.0   0.996528       0.0
# 483836        1.0             7.0   0.997222       0.0
# 483837        1.0             7.0   0.997917       0.0
# 483838        1.0             7.0   0.998611       0.0
# 483839        1.0             7.0   0.999306       0.0
#
# [483840 rows x 4 columns]
#         Pora roku  Dzień tygodnia  Czas dnia  Przeplyw
# 0             2.0             1.0   0.000000       0.0
# 1             2.0             1.0   0.000694       0.0
# 2             2.0             1.0   0.001389       0.0
# 3             2.0             1.0   0.002083       0.0
# 4             2.0             1.0   0.002778       0.0
# ...           ...             ...        ...       ...
# 645115        1.0             7.0   0.996528       0.0
# 645116        1.0             7.0   0.997222       0.0
# 645117        1.0             7.0   0.997917       0.0
# 645118        1.0             7.0   0.998611       0.0
# 645119        1.0             7.0   0.999306       0.0
#
# [645120 rows x 4 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Kuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1628
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Kuba\Desktop\inzynierka\data_nowe\Skrypt.IPYNB Cell 7 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/Kuba/Desktop/inzynierka/data_nowe/Skrypt.IPYNB#X10sZmlsZQ%3D%3D?line=19'>20</a>     hours, minutes,null= time.split(":")
#      <a href='vscode-notebook-cell:/c%3A/Users/Kuba/Desktop/inzynierka/data_nowe/Skrypt.IPYNB#X10sZmlsZQ%3D%3D?line=20'>21</a>     time=(int(hours)*60+int(minutes))/(60*24)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Kuba/Desktop/inzynierka/data_nowe/Skrypt.IPYNB#X10sZmlsZQ%3D%3D?line=22'>23</a>     dane_1.loc[len(dane_1)]={'Pora roku':2,'Dzień tygodnia':dni_tygodnia_mapa[ans.strftime("%A")],'Czas dnia':time, 'Przeplyw': dataset.loc[i,"Summer_Water_Consumption"]}
#      <a href='vscode-notebook-cell:/c%3A/Users/Kuba/Desktop/inzynierka/data_nowe/Skrypt.IPYNB#X10sZmlsZQ%3D%3D?line=23'>24</a> for i in range(len(dataset)):
#      <a href='vscode-notebook-cell:/c%3A/Users/Kuba/Desktop/inzynierka/data_nowe/Skrypt.IPYNB#X10sZmlsZQ%3D%3D?line=24'>25</a>     # ----------------------
#      <a href='vscode-notebook-cell:/c%3A/Users/Kuba/Desktop/inzynierka/data_nowe/Skrypt.IPYNB#X10sZmlsZQ%3D%3D?line=25'>26</a>     # ----------------------
#      <a href='vscode-notebook-cell:/c%3A/Users/Kuba/Desktop/inzynierka/data_nowe/Skrypt.IPYNB#X10sZmlsZQ%3D%3D?line=26'>27</a>     dt = dataset.loc[i,"Autumn_Timestamps"]
#
# File c:\Users\Kuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:881, in _LocationIndexer.__setitem__(self, key, value)
#     879 else:
#     880     key = com.apply_if_callable(key, self.obj)
# --> 881 indexer = self._get_setitem_indexer(key)
#     882 self._has_valid_setitem_indexer(key)
#     884 iloc = self if self.name == "iloc" else self.obj.iloc
#
# File c:\Users\Kuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:764, in _LocationIndexer._get_setitem_indexer(self, key)
#     760 if isinstance(key, range):
#     761     # GH#45479 test_loc_setitem_range_key
#     762     key = list(key)
# --> 764 return self._convert_to_indexer(key, axis=0)
#
# File c:\Users\Kuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1455, in _LocIndexer._convert_to_indexer(self, key, axis)
#    1448 if is_scalar(key) or (
#    1449     isinstance(labels, MultiIndex) and is_hashable(key) and not contains_slice
#    1450 ):
#    1451     # Otherwise get_loc will raise InvalidIndexError
#    1452
#    1453     # if we are a label return me
#    1454     try:
# -> 1455         return labels.get_loc(key)
#    1456     except LookupError:
#    1457         if isinstance(key, tuple) and isinstance(labels, MultiIndex):
#
# File c:\Users\Kuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3793, in Index.get_loc(self, key)
#    3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#    3792     if isinstance(casted_key, slice) or (
# -> 3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
#    3797     raise KeyError(key) from err
#
# File <frozen abc>:117, in __instancecheck__(cls, instance)
#
# KeyboardInterrupt:
